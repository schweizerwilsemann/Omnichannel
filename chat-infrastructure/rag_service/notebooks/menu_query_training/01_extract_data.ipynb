# %% [markdown]
# # 01 · Extract Clarification Data
#
# Fetch menu-query clarification logs through the analytics API and cache the raw payload for downstream processing.
#
# ## Prerequisites
# - FastAPI service is running with the analytics router enabled.
# - Admin key available in `RAG_ADMIN_API_KEY` (matches backend `.env`).
# - Optional filters via `ANALYTICS_START_AT`, `ANALYTICS_END_AT`, `ANALYTICS_FETCH_LIMIT`.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in e:\omnichannel\omnichannel\.venv\lib\site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\omnichannel\omnichannel\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# Saved 6 rows to notebooks\menu_query_training\artifacts\clarifications_raw.parquet
# WindowsPath('notebooks/menu_query_training/artifacts/clarifications_raw.parquet')

# %%
import os
from pathlib import Path

try:
    from dotenv import load_dotenv
except ImportError:
    load_dotenv = None

import pandas as pd
import requests

DATA_DIR = Path("notebooks/menu_query_training/artifacts")
DATA_DIR.mkdir(parents=True, exist_ok=True)

if load_dotenv:
    env_candidates = [
        Path.cwd() / ".env",
        Path.cwd().parent / ".env",
        Path.cwd().parent.parent / ".env",
        Path.cwd() / "chat-infrastructure" / "rag_service" / ".env",
        Path.cwd() / "be" / ".env"
    ]
    for env_path in env_candidates:
        if env_path.exists():
            load_dotenv(env_path, override=False)

BASE_URL = os.getenv("ANALYTICS_API_URL", "http://localhost:8081").rstrip('/')
ADMIN_KEY = os.getenv("RAG_ADMIN_API_KEY")
if not ADMIN_KEY:
    raise ValueError("RAG_ADMIN_API_KEY is required to call the analytics endpoint.")

params = {
    "limit": int(os.getenv("ANALYTICS_FETCH_LIMIT", "500")),
}
start_at = os.getenv("ANALYTICS_START_AT")
end_at = os.getenv("ANALYTICS_END_AT")
if start_at:
    params["start_at"] = start_at
if end_at:
    params["end_at"] = end_at

response = requests.get(
    f"{BASE_URL}/analytics/menu-query/clarifications",
    headers={"x-rag-admin-key": ADMIN_KEY},
    params=params,
    timeout=30
)
response.raise_for_status()
payload = response.json()
items = payload.get("items", [])
print(f"Fetched {len(items)} clarification rows")
if not items:
    raise ValueError("No clarifications returned; adjust filters or confirm data exists.")

df = pd.DataFrame(items)
df.head()
# Out:
# Fetched 6 clarification rows
#                        clarification_id           query_time  \
# 0  a0ea29ce-5422-4e87-8341-648cf46b3c82  2025-10-29T02:29:12
# 1  4d24c2a3-5fbd-43fa-a180-8162ddfe8b20  2025-10-28T17:37:56
# 2  e35286d1-7d4c-42ae-8d18-311abfc0ccb3  2025-10-28T17:37:24
# 3  98e40dc4-bae8-48fb-8709-af3bf0c49c7e  2025-10-28T17:23:25
# 4  b83cfad9-be67-4dc0-9f63-0d0a08b15b9d  2025-10-28T17:11:37
#
#                  raw_query         normalized_query               tokens  \
# 0    Any vegetarian pasta?    any vegetarian pasta?  [vegetarian, pasta]
# 1             dishes today             dishes today      [dishes, today]
# 2    Any vegetarian pasta?    any vegetarian pasta?  [vegetarian, pasta]
# 3  I want some cold drinks  i want some cold drinks       [cold, drinks]
# 4  I want some cold drinks  i want some cold drinks       [cold, drinks]
#
#                                              intents  ambiguity_score  \
# 0  {'spice': None, 'courses': ['pasta'], 'tempera...            0.978
# 1  {'spice': None, 'courses': [], 'temperature': ...            0.958
# 2  {'spice': None, 'courses': ['pasta'], 'tempera...            0.978
# 3  {'spice': None, 'courses': ['beverage'], 'temp...            0.800
# 4  {'spice': None, 'courses': ['beverage'], 'temp...            0.800
#
#                                       query_metadata  \
# 0  {'available': True, 'tokenCount': 2, 'queryLen...
# 1  {'available': True, 'tokenCount': 2, 'queryLen...
# 2  {'available': True, 'tokenCount': 2, 'queryLen...
# 3  {'available': True, 'tokenCount': 2, 'queryLen...
# 4  {'available': True, 'tokenCount': 2, 'queryLen...
#
#                                        question_text  \
# 0  Would you like to focus on Pasta & Risotto, Pi...
# 1  Would you like to focus on Main Courses, Pasta...
# 2  Would you like to focus on Pasta & Risotto, Pi...
# 3  Would you like to focus on Beverages or Wine &...
# 4  Would you like to focus on Beverages or Wine &...
#
#                               clarification_metadata        user_reply  \
# 0  {'options': ['Pasta & Risotto', 'Pizza', 'Soup...    Soups & Salads
# 1  {'options': ['Main Courses', 'Pasta & Risotto'...      Main Courses
# 2  {'options': ['Pasta & Risotto', 'Pizza', 'Soup...    Soups & Salads
# 3  {'options': ['Beverages', 'Wine & Cocktails'],...  Wine & Cocktails
# 4  {'options': ['Beverages', 'Wine & Cocktails'],...     with alcohol?
#
#   resolved_intent resolution_status                      resolved_item_id  \
# 0  freeform-input         CLARIFIED  dc289bdb-6d3e-46a6-a4b8-bb0b90ef9745
# 1  freeform-input         CLARIFIED  9cd431c3-48be-459a-a325-574dad59174c
# 2  freeform-input         CLARIFIED  dc289bdb-6d3e-46a6-a4b8-bb0b90ef9745
# 3  freeform-input         CLARIFIED  afe68abc-405b-4a1b-bde9-d9f1f92457cb
# 4  freeform-input         CLARIFIED  afe68abc-405b-4a1b-bde9-d9f1f92457cb
#
#     resolved_item_name
# 0  Roasted Tomato Soup
# 1      Seared Scallops
# 2  Roasted Tomato Soup
# 3        Aperol Spritz
# 4        Aperol Spritz

# %%
import os
from pathlib import Path

import pandas as pd
import requests

DATA_DIR = Path("notebooks/menu_query_training/artifacts")
DATA_DIR.mkdir(parents=True, exist_ok=True)

BASE_URL = os.getenv("ANALYTICS_API_URL", "http://localhost:8081").rstrip('/')
ADMIN_KEY = os.getenv("RAG_ADMIN_API_KEY")
if not ADMIN_KEY:
    raise ValueError("RAG_ADMIN_API_KEY is required to call the analytics endpoint.")

params = {
    "limit": int(os.getenv("ANALYTICS_FETCH_LIMIT", "500")),
}
start_at = os.getenv("ANALYTICS_START_AT")
end_at = os.getenv("ANALYTICS_END_AT")
if start_at:
    params["start_at"] = start_at
if end_at:
    params["end_at"] = end_at

response = requests.get(
    f"{BASE_URL}/analytics/menu-query/clarifications",
    headers={"x-rag-admin-key": ADMIN_KEY},
    params=params,
    timeout=30
)
response.raise_for_status()
payload = response.json()
items = payload.get("items", [])
print(f"Fetched {len(items)} clarification rows")
if not items:
    raise ValueError("No clarifications returned; adjust filters or confirm data exists.")

df = pd.DataFrame(items)
df.head()
# Out:
# Fetched 6 clarification rows
#                        clarification_id           query_time  \
# 0  a0ea29ce-5422-4e87-8341-648cf46b3c82  2025-10-29T02:29:12
# 1  4d24c2a3-5fbd-43fa-a180-8162ddfe8b20  2025-10-28T17:37:56
# 2  e35286d1-7d4c-42ae-8d18-311abfc0ccb3  2025-10-28T17:37:24
# 3  98e40dc4-bae8-48fb-8709-af3bf0c49c7e  2025-10-28T17:23:25
# 4  b83cfad9-be67-4dc0-9f63-0d0a08b15b9d  2025-10-28T17:11:37
#
#                  raw_query         normalized_query               tokens  \
# 0    Any vegetarian pasta?    any vegetarian pasta?  [vegetarian, pasta]
# 1             dishes today             dishes today      [dishes, today]
# 2    Any vegetarian pasta?    any vegetarian pasta?  [vegetarian, pasta]
# 3  I want some cold drinks  i want some cold drinks       [cold, drinks]
# 4  I want some cold drinks  i want some cold drinks       [cold, drinks]
#
#                                              intents  ambiguity_score  \
# 0  {'spice': None, 'courses': ['pasta'], 'tempera...            0.978
# 1  {'spice': None, 'courses': [], 'temperature': ...            0.958
# 2  {'spice': None, 'courses': ['pasta'], 'tempera...            0.978
# 3  {'spice': None, 'courses': ['beverage'], 'temp...            0.800
# 4  {'spice': None, 'courses': ['beverage'], 'temp...            0.800
#
#                                       query_metadata  \
# 0  {'available': True, 'tokenCount': 2, 'queryLen...
# 1  {'available': True, 'tokenCount': 2, 'queryLen...
# 2  {'available': True, 'tokenCount': 2, 'queryLen...
# 3  {'available': True, 'tokenCount': 2, 'queryLen...
# 4  {'available': True, 'tokenCount': 2, 'queryLen...
#
#                                        question_text  \
# 0  Would you like to focus on Pasta & Risotto, Pi...
# 1  Would you like to focus on Main Courses, Pasta...
# 2  Would you like to focus on Pasta & Risotto, Pi...
# 3  Would you like to focus on Beverages or Wine &...
# 4  Would you like to focus on Beverages or Wine &...
#
#                               clarification_metadata        user_reply  \
# 0  {'options': ['Pasta & Risotto', 'Pizza', 'Soup...    Soups & Salads
# 1  {'options': ['Main Courses', 'Pasta & Risotto'...      Main Courses
# 2  {'options': ['Pasta & Risotto', 'Pizza', 'Soup...    Soups & Salads
# 3  {'options': ['Beverages', 'Wine & Cocktails'],...  Wine & Cocktails
# 4  {'options': ['Beverages', 'Wine & Cocktails'],...     with alcohol?
#
#   resolved_intent resolution_status                      resolved_item_id  \
# 0  freeform-input         CLARIFIED  dc289bdb-6d3e-46a6-a4b8-bb0b90ef9745
# 1  freeform-input         CLARIFIED  9cd431c3-48be-459a-a325-574dad59174c
# 2  freeform-input         CLARIFIED  dc289bdb-6d3e-46a6-a4b8-bb0b90ef9745
# 3  freeform-input         CLARIFIED  afe68abc-405b-4a1b-bde9-d9f1f92457cb
# 4  freeform-input         CLARIFIED  afe68abc-405b-4a1b-bde9-d9f1f92457cb
#
#     resolved_item_name
# 0  Roasted Tomato Soup
# 1      Seared Scallops
# 2  Roasted Tomato Soup
# 3        Aperol Spritz
# 4        Aperol Spritz

# %%
import json

# Ensure pandas and Path are available without re-importing if already present
if 'pd' not in globals():
    import pandas as pd

from pathlib import Path

# Ensure DATA_DIR exists (do not overwrite if already defined in other cells)
if 'DATA_DIR' not in globals():
    DATA_DIR = Path("notebooks/menu_query_training/artifacts")
    DATA_DIR.mkdir(parents=True, exist_ok=True)

# If df is not present in the notebook, try loading the cached parquet as a fallback
if 'df' not in globals():
    parquet_path = DATA_DIR / 'clarifications_raw.parquet'
    if parquet_path.exists():
        try:
            df = pd.read_parquet(parquet_path)
            print(f"Loaded dataframe from {parquet_path}")
        except Exception as e:
            raise RuntimeError(f"Failed to read {parquet_path}: {e}")
    else:
        raise RuntimeError(
            "No dataframe 'df' found in the notebook and clarifications_raw.parquet does not exist. "
            "Run the extraction cell first to populate the dataframe or ensure the parquet file is present."
        )

def _to_serializable(value):
    if isinstance(value, (dict, list)):
        return json.dumps(value, ensure_ascii=False)
    return value

serializable_df = df.copy()
for column in serializable_df.columns:
    if serializable_df[column].dtype == 'object':
        if serializable_df[column].apply(lambda x: isinstance(x, (dict, list))).any():
            serializable_df[column] = serializable_df[column].apply(_to_serializable)

output_path = DATA_DIR / 'clarifications_raw.parquet'
serializable_df.to_parquet(output_path, index=False)
print(f'Saved {len(serializable_df)} rows to {output_path}')
output_path
# Out:
# Saved 6 rows to notebooks\menu_query_training\artifacts\clarifications_raw.parquet
# WindowsPath('notebooks/menu_query_training/artifacts/clarifications_raw.parquet')

# %%
pip install pyarrow
# Out:
# Collecting pyarrow
#   Downloading pyarrow-22.0.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Downloading pyarrow-22.0.0-cp313-cp313-win_amd64.whl (28.0 MB)
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    - -------------------------------------- 0.8/28.0 MB 10.7 MB/s eta 0:00:03
#    --------- ------------------------------ 6.8/28.0 MB 38.0 MB/s eta 0:00:01
#    ------------------------------- -------- 21.8/28.0 MB 46.2 MB/s eta 0:00:01
#    ---------------------------------------- 28.0/28.0 MB 45.2 MB/s  0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-22.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in e:\omnichannel\omnichannel\.venv\lib\site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from fastparquet) (2.3.3)
# Requirement already satisfied: numpy in e:\omnichannel\omnichannel\.venv\lib\site-packages (from fastparquet) (2.3.4)
# Requirement already satisfied: cramjam>=2.3 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in e:\omnichannel\omnichannel\.venv\lib\site-packages (from fastparquet) (2025.9.0)
# Requirement already satisfied: packaging in e:\omnichannel\omnichannel\.venv\lib\site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\omnichannel\omnichannel\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
output_path = DATA_DIR / "clarifications_raw.parquet"
df.to_parquet(output_path, index=False)
print(f"Saved {len(df)} rows to {output_path}")
output_path
# Out:
# Saved 6 rows to notebooks\menu_query_training\artifacts\clarifications_raw.parquet
# WindowsPath('notebooks/menu_query_training/artifacts/clarifications_raw.parquet')
